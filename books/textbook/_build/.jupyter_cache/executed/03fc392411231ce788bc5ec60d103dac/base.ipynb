# %%
# %run -i ../python/common.py
publish=False

if not publish:
    # cleanup any old state
    bashCmds('''[[ -d lec3 ]] && rm -rf mydir
    [[ -a myinfo ]] && rm myinfo''')
else:
    bashCmds('''rm -rf ~/*''')
    
closeAllOpenTtySessions()

# %%
appdir=os.getenv('HOME')
appdir=appdir + "/parser"
TermShellCmd("ls ")
output = runTermCmd("[[ -d " + appdir + " ]] &&  rm -rf "+ appdir + 
             ";cp -r ../src/parser " + appdir)
bash = BashSession(cwd=appdir)

# %%
# This cell is removed in the html, but displays the code listing in the Jupyter notebook. 
file = appdir + "/Makefile"
text_file = open(file, "r")
data = text_file.read()
data = numberLines(data)
text_file.close()                                                                                             
md_text = '''                                                                                                                        
``` ''' + "sh" + '''                                                                                                                     
''' + data + '''                                                                                                                         
```                                                                                                                                      
'''
display (Markdown(md_text))
#display (Markdown('<font size=".5rem">' + md_text +'</font>'))
# Out:
#
# ``` sh
# 0: override CFLAGS := -std=gnu99 -O0 -Wall -Werror -g  -fsanitize=undefined $(CFLAGS) -I.
# 1: override LDFLAGS := -fsanitize=undefined -fsanitize=leak $(LDLAGS)
# 2: CC = gcc
# 3:
# 4: # I generally make the first rule run all the tests
# 5: all: check
# 6:
# 7: # rule for making the parser.o  that is needed by all the test programs
# 8: myshell_parser.o: myshell_parser.c myshell_parser.h
# 9:
# 10:
# 11: # each of the test files depend on their own .c and myshell_parser.h
# 12: test_simple_input.o: test_simple_input.c myshell_parser.h
# 13: test_simple_pipe.o: test_simple_pipe.c myshell_parser.h
# 14:
# 15: # each of the test programs executables are generated by combining the generated .o with the parser.o
# 16: test_simple_input : test_simple_input.o myshell_parser.o
# 17: test_simple_pipe : test_simple_pipe.o myshell_parser.o
# 18:
# 19: # Add any additional tests here
# 20: test_files=./test_simple_input ./test_simple_pipe
# 21:
# 22: .PHONY: clean check checkprogs all
# 23:
# 24: # Build all of the test program
# 25: checkprogs: $(test_files)
# 26:
# 27: check: checkprogs
# 28: 	/bin/bash run_tests.sh $(test_files)
# 29:
# 30: clean:
# 31: 	rm -f *~ *.o $(test_files) $(test_o_files)
#
# ```

# %%
bash.run("make clean ; make checkprogs")
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…

# %%
bash.run("make checkprogs")
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…

# %%
bash.run("touch test_simple_input.c ; make checkprogs")
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…

# %%
bash.run("touch myshell_parser.c ; make checkprogs")
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…

# %%
bash.run("touch myshell_parser.h ; make checkprogs")
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
